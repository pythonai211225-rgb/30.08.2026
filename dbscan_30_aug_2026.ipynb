# %% [markdown]
# ![image.png](attachment:b21bffbf-102d-4689-81a6-0f078bffb95e.png)

# %% [markdown]
# ![image.png](attachment:b1f56e6d-3821-4c85-9aec-dbec3c7046f9.png)

# %% [markdown]
# ![image.png](attachment:c67410e1-5823-40ef-bee1-e246859577dc.png)

# %% [markdown]
# ![image.png](attachment:a9722326-bb4a-4259-82bf-6dea0e34a64b.png)

# %% [markdown]
# ![image.png](attachment:9c673857-6ccf-4aa8-8af6-882277a1c39c.png)

# %% [markdown]
# ![image.png](attachment:c2e94860-4866-42e2-bfac-1e817eb49305.png)

# %% [markdown]
# ![image.png](attachment:51f8cc82-7003-483c-b28e-069e266e5f55.png)

# %% [markdown]
# ![image.png](attachment:edaf2e03-4b1f-41d3-a615-94a708bce3a6.png)

# %% [markdown]
# ![image.png](attachment:963f4c1c-4a53-4241-8a83-eea808d0168a.png)

# %% [markdown]
# ![image.png](attachment:2aab2943-6a49-4d59-bea3-b8b15a1a2e54.png)

# %% [markdown]
# ![image.png](attachment:34583b6e-0512-4f6e-9eaf-9956aca9a375.png)

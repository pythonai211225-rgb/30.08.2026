# %% [markdown]
# <h1>Hierarchical Clustering</h1>

# %% [markdown]
# ![image.png](attachment:cf5d1951-bfbc-4f34-865d-2a31841fc71e.png)

# %% [markdown]
# ![image.png](attachment:d2019f0c-3b11-4662-8a34-352750b088ba.png)

# %% [markdown]
# ![image.png](attachment:23887318-a2a6-40e7-93be-837f11833061.png)

# %% [markdown]
# ![image.png](attachment:504bc214-d8e3-4867-bd7e-71e58d789a97.png)

# %% [markdown]
# ![image.png](attachment:0e6be0d2-2b52-4088-b90d-02c5325d9af7.png)

# %% [markdown]
# ![image.png](attachment:586c7394-b40d-47d4-bc61-46c57b360c0e.png)

# %% [markdown]
# ![image.png](attachment:9e131388-5357-4439-8940-8fe89306c2e3.png)

# %% [markdown]
# ![image.png](attachment:0d25a6cd-7222-4808-88b0-d5b23b4d538f.png)

# %% [markdown]
# ![image.png](attachment:cea004c1-cf58-413f-b76f-11ddde317848.png)

# %% [markdown]
# ![image.png](attachment:a2075f6d-da55-40df-8cfa-7885bda80951.png)

# %% [markdown]
# ![image.png](attachment:daadbff8-cc74-4aeb-9370-1128b1d2720e.png)

# %% [markdown]
# ![image.png](attachment:e768c226-1d5e-4f6b-a043-7deea0ff8b5e.png)

# %% [markdown]
# ![image.png](attachment:f82ab212-4d48-461c-a200-e5c80be42147.png)

# %% [markdown]
# ![image.png](attachment:d207a206-6cf0-40c7-9cab-11d02d83e69f.png)

# %% [markdown]
# ![image.png](attachment:a9f8b87f-24fc-4bb0-ac16-6ae30cd97856.png)
